# %%
import os

os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("incredible45/Gutenberg-BookCorpus-Cleaned-Data-English")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Resolving data files:   0%|          | 0/43 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/43 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/43 [00:00<?, ?files/s]
# data/train-00000-of-00043.parquet:   0%|          | 0.00/335M [00:00<?, ?B/s]
# data/train-00001-of-00043.parquet:   0%|          | 0.00/304M [00:00<?, ?B/s]
# data/train-00002-of-00043.parquet:   0%|          | 0.00/342M [00:00<?, ?B/s]
# data/train-00003-of-00043.parquet:   0%|          | 0.00/308M [00:00<?, ?B/s]
# data/train-00004-of-00043.parquet:   0%|          | 0.00/337M [00:00<?, ?B/s]
# data/train-00005-of-00043.parquet:   0%|          | 0.00/278M [00:00<?, ?B/s]
# data/train-00006-of-00043.parquet:   0%|          | 0.00/306M [00:00<?, ?B/s]
# data/train-00007-of-00043.parquet:   0%|          | 0.00/317M [00:00<?, ?B/s]
# data/train-00008-of-00043.parquet:   0%|          | 0.00/309M [00:00<?, ?B/s]
# data/train-00009-of-00043.parquet:   0%|          | 0.00/291M [00:00<?, ?B/s]
# data/train-00010-of-00043.parquet:   0%|          | 0.00/289M [00:00<?, ?B/s]
# data/train-00011-of-00043.parquet:   0%|          | 0.00/295M [00:00<?, ?B/s]
# data/train-00012-of-00043.parquet:   0%|          | 0.00/320M [00:00<?, ?B/s]
# data/train-00013-of-00043.parquet:   0%|          | 0.00/241M [00:00<?, ?B/s]
# data/train-00014-of-00043.parquet:   0%|          | 0.00/242M [00:00<?, ?B/s]
# data/train-00015-of-00043.parquet:   0%|          | 0.00/263M [00:00<?, ?B/s]
# data/train-00016-of-00043.parquet:   0%|          | 0.00/284M [00:00<?, ?B/s]
# data/train-00017-of-00043.parquet:   0%|          | 0.00/259M [00:00<?, ?B/s]
# data/train-00018-of-00043.parquet:   0%|          | 0.00/245M [00:00<?, ?B/s]
# data/train-00019-of-00043.parquet:   0%|          | 0.00/279M [00:00<?, ?B/s]
# data/train-00020-of-00043.parquet:   0%|          | 0.00/330M [00:00<?, ?B/s]
# data/train-00021-of-00043.parquet:   0%|          | 0.00/283M [00:00<?, ?B/s]
# data/train-00022-of-00043.parquet:   0%|          | 0.00/335M [00:00<?, ?B/s]
# data/train-00023-of-00043.parquet:   0%|          | 0.00/363M [00:00<?, ?B/s]
# data/train-00024-of-00043.parquet:   0%|          | 0.00/349M [00:00<?, ?B/s]
# data/train-00025-of-00043.parquet:   0%|          | 0.00/359M [00:00<?, ?B/s]
# data/train-00026-of-00043.parquet:   0%|          | 0.00/326M [00:00<?, ?B/s]
# data/train-00027-of-00043.parquet:   0%|          | 0.00/344M [00:00<?, ?B/s]
# data/train-00028-of-00043.parquet:   0%|          | 0.00/306M [00:00<?, ?B/s]
# data/train-00029-of-00043.parquet:   0%|          | 0.00/297M [00:00<?, ?B/s]
# data/train-00030-of-00043.parquet:   0%|          | 0.00/314M [00:00<?, ?B/s]
# data/train-00031-of-00043.parquet:   0%|          | 0.00/334M [00:00<?, ?B/s]
# data/train-00032-of-00043.parquet:   0%|          | 0.00/337M [00:00<?, ?B/s]
# data/train-00033-of-00043.parquet:   0%|          | 0.00/309M [00:00<?, ?B/s]
# data/train-00034-of-00043.parquet:   0%|          | 0.00/290M [00:00<?, ?B/s]
# data/train-00035-of-00043.parquet:   0%|          | 0.00/246M [00:00<?, ?B/s]
# data/train-00036-of-00043.parquet:   0%|          | 0.00/232M [00:00<?, ?B/s]
# data/train-00037-of-00043.parquet:   0%|          | 0.00/229M [00:00<?, ?B/s]
# data/train-00038-of-00043.parquet:   0%|          | 0.00/268M [00:00<?, ?B/s]
# data/train-00039-of-00043.parquet:   0%|          | 0.00/268M [00:00<?, ?B/s]
# data/train-00040-of-00043.parquet:   0%|          | 0.00/325M [00:00<?, ?B/s]
# data/train-00041-of-00043.parquet:   0%|          | 0.00/304M [00:00<?, ?B/s]
# data/train-00042-of-00043.parquet:   0%|          | 0.00/295M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/58653 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/35 [00:00<?, ?it/s]
